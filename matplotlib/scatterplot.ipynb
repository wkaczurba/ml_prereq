# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.random.randn(100, 2)

# %%
plt.scatter(X[:,0], X[:, 1])

# %%
X = np.random.randn(200, 2)
X[:50] += 3
Y = np.zeros(200)
Y[:50] = 1

# %%
plt.scatter(X[:,0], X[:,1], c=Y)

# %%
X = np.random.randn(200)
plt.hist(X)
# Out:
# (array([ 3.,  3., 11., 25., 36., 48., 32., 26., 13.,  3.]),
#  array([-2.83044163, -2.30521433, -1.77998704, -1.25475974, -0.72953245,
#         -0.20430516,  0.32092214,  0.84614943,  1.37137673,  1.89660402,
#          2.42183132]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(X, bins=50)
# Out:
# (array([ 1.,  0.,  1.,  0.,  1.,  0.,  1.,  1.,  0.,  1.,  4.,  1.,  2.,
#          1.,  3.,  5.,  5.,  9.,  3.,  3.,  9.,  6.,  6.,  8.,  7.,  7.,
#          8.,  7., 13., 13.,  1.,  9.,  6.,  9.,  7.,  4.,  6.,  3.,  8.,
#          5.,  4.,  5.,  2.,  0.,  2.,  1.,  0.,  1.,  0.,  1.]),
#  array([-2.83044163, -2.72539617, -2.62035071, -2.51530525, -2.41025979,
#         -2.30521433, -2.20016887, -2.09512341, -1.99007796, -1.8850325 ,
#         -1.77998704, -1.67494158, -1.56989612, -1.46485066, -1.3598052 ,
#         -1.25475974, -1.14971428, -1.04466883, -0.93962337, -0.83457791,
#         -0.72953245, -0.62448699, -0.51944153, -0.41439607, -0.30935061,
#         -0.20430516, -0.0992597 ,  0.00578576,  0.11083122,  0.21587668,
#          0.32092214,  0.4259676 ,  0.53101306,  0.63605852,  0.74110397,
#          0.84614943,  0.95119489,  1.05624035,  1.16128581,  1.26633127,
#          1.37137673,  1.47642219,  1.58146765,  1.6865131 ,  1.79155856,
#          1.89660402,  2.00164948,  2.10669494,  2.2117404 ,  2.31678586,
#          2.42183132]),
#  <a list of 50 Patch objects>)

# %%
X = np.random.random(10000)
plt.hist(X, bins=50);
