# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.random.randn(100, 2)

# %%
plt.scatter(X[:,0], X[:, 1])

# %%
X =
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5bf0edaa67d9> in <module>
# ----> 1 x[:50] += 3
#
# NameError: name 'x' is not defined
